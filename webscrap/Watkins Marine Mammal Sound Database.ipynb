# %%
import warnings
warnings.filterwarnings('ignore')

import copy
import pandas as pd 

# Requests sends and recieves HTTP requests.
import requests 

# Beautiful soup parses HTML documents in python.
from bs4 import BeautifulSoup

from pymongo import MongoClient
import pprint

# %% [markdown]
# # Step 1: Check out the website in a browser
#
# 1: The table and wav is inside of body /html/body/div[3]/div/div/table/tbody/tr[2]/td[4]/a

# %% [markdown]
# # Step 2: Send a Get request for the data.

# %%
watkins_sounds = "https://cis.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3D"

r = requests.get(watkins_sounds)

# %%
r # A status code of 200 means that everything went well
# Out:
# <Response [200]>

# %% [markdown]
# We can check out the raw hypertext in the content attribute of the request.

# %%
r.content
# Out:
# b'\n<!doctype html>\n<html class="no-js" lang="en">\n<head><script type="text/javascript" src="/cf_scripts/scripts/cfform.js"></script>\n<script type="text/javascript" src="/cf_scripts/scripts/masks.js"></script>\n\n    <meta charset="utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" />\n    <title>Watkins Marine Mammal Sound Database</title>\n    <link rel="stylesheet" href="https://www.whoi.edu/cf_headers/watkins/css/foundation.css" />\n    <link rel="stylesheet" href="https://www.whoi.edu/cf_headers/watkins/css/styles.css" />\n    <link rel="stylesheet" href="https://www.whoi.edu/cf_headers/watkins/css/audioplayer.css" />\n    <script src="https://www.whoi.edu/cf_headers/watkins/js/vendor/modernizr.js"></script>\n    <script>\n$(\'getSpeciesCommon\').change(function(){\n    var url = $(this).val();\n    window.location = url;\n});\n\t</script>\n\n<script language="JavaScript">\n<!--\nfunction goTo(pagename) {\n    if ((-1 < pagename.selectedIndex) &&\n        (pagename.options[pagename.selectedIndex].value != "nil")) {\n        val = pagename.options[pagename.selectedIndex].value;\n        if(val!="NoValue") {\n            parent.location.href=val;\n            return true;\n        }\n    }\n}\n\nfunction popUpWin(theurl)\n{\n    window.open(theurl,"Metadata",\n"height=375,width=700,location=0,menubar=0,resizable=1,scrollbars=1,status=0,titlebar=1,toolbar=0,hotkeys=0,screenx=0,screeny=0,left=10,top=10");\n}\n\n//-->\n</script>\n<script type="text/javascript">\n<!--\n    _CF_checkjump1 = function(_CF_this)\n    {\n        //reset on submit\n        _CF_error_exists = false;\n        _CF_error_messages = new Array();\n        _CF_error_fields = new Object();\n        _CF_FirstErrorField = null;\n\n\n        //display error messages and return success\n        if( _CF_error_exists )\n        {\n            if( _CF_error_messages.length > 0 )\n            {\n                // show alert() message\n                _CF_onErrorAlert(_CF_error_messages);\n                // set focus to first form error, if the field supports js focus().\n                if( _CF_this[_CF_FirstErrorField].type == "text" )\n                { _CF_this[_CF_FirstErrorField].focus(); }\n\n            }\n            return false;\n        }else {\n            return true;\n        }\n    }\n//-->\n</script>\n<script type="text/javascript">\n<!--\n    _CF_checkjump2 = function(_CF_this)\n    {\n        //reset on submit\n        _CF_error_exists = false;\n        _CF_error_messages = new Array();\n        _CF_error_fields = new Object();\n        _CF_FirstErrorField = null;\n\n\n        //display error messages and return success\n        if( _CF_error_exists )\n        {\n            if( _CF_error_messages.length > 0 )\n            {\n                // show alert() message\n                _CF_onErrorAlert(_CF_error_messages);\n                // set focus to first form error, if the field supports js focus().\n                if( _CF_this[_CF_FirstErrorField].type == "text" )\n                { _CF_this[_CF_FirstErrorField].focus(); }\n\n            }\n            return false;\n        }else {\n            return true;\n        }\n    }\n//-->\n</script>\n</head>\n\n<body>\n\n<div class="brand">\n  <div class="row">\n    <div class="medium-6 columns"> \n\t<a href="https://www.whalingmuseum.org/"><img src="https://www.whoi.edu/cf_headers/watkins/img/NBWM.png" \n\talt=""/></a> </div>\n    \n    <div class="medium-6 columns"> <a href="https://www.whoi.edu"><img \n\tsrc="https://www.whoi.edu/cf_headers/watkins/img/woodsholeoceanographic.png" \n\talt="Woods Hole Oceanographic Institution" style="padding-top:1.15em;float:right;"/></a> </div>\n  </div> \n</div>\n\n    \n\n<div class="banner">   \n  <div class="row">\n    <div class="large-12 columns">\n      <h1><a href="index.cfm"><img src="https://www.whoi.edu/cf_headers/watkins/img/logo.png" alt=""/> \n\tWatkins Marine Mammal Sound Database</a></h1>\n    </div>\n  </div ...

# %%
# connect to the hosted MongoDB instance
client = MongoClient('localhost', 27017)

# %%
# Create a database
db = client['marine_sounds']

# %%
# Create a collection called dolphins

short_finned_pilot_whale = db['marine_sounds']

# %%
short_finned_pilot_whale
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'marine_sounds'), 'marine_sounds')

# %% [markdown]
# # Step 3: Save all the hypertext into mongo for later use.

# %%
short_finned_pilot_whale.insert_one({'html': r.content}) # change name to collections
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 short_finned_pilot_whale.insert_one({'html': r.content}) # change name to collections
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/pymongo/collection.py:621, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     617     document["_id"] = ObjectId()
#     619 write_concern = self._write_concern_for(session)
#     620 return InsertOneResult(
# --> 621     self._insert_one(
#     622         document,
#     623         ordered=True,
#     624         write_concern=write_concern,
#     625         op_id=None,
#     626         bypass_doc_val=bypass_document_validation,
#     627         session=session,
#     628         comment=comment,
#     629     ),
#     630     write_concern.acknowledged,
#     631 )
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/pymongo/collection.py:562, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     550     result = sock_info.command(
#     551         self.__database.name,
#     552         command,
#    (...)
#     557         retryable_write=retryable_write,
#     558     )
#     560     _check_write_command_response(result)
# --> 562 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     564 if not isinstance(doc, RawBSONDocument):
#     565     return doc.get("_id")
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/pymongo/mongo_client.py:1475, in MongoClient._retryable_write(self, retryable, func, session)
#    1473 def _retryable_write(self, retryable, func, session):
#    1474     """Internal retryable write helper."""
# -> 1475     with self._tmp_session(session) as s:
#    1476         return self._retry_with_session(retryable, func, s, None)
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     115 del self.args, self.kwds, self.func
#     116 try:
# --> 117     return next(self.gen)
#     118 except StopIteration:
#     119     raise RuntimeError("generator didn't yield") from None
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/pymongo/mongo_client.py:1757, in MongoClient._tmp_session(self, session, close)
#    1754     yield session
#    1755     return
# -> 1757 s = self._ensure_session(session)
#    1758 if s:
#    1759     try:
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/pymongo/mongo_client.py:1740, in MongoClient._ensure_session(self, session)
#    1735     return session
#    1737 try:
#    1738     # Don't make implicit sessions causally consistent. Applications
#    1739     # should always opt-in.
# -> 1740     return self.__start_session(True, causal_consistency=False)
#    1741 except (ConfigurationError, InvalidOperation):
#    1742     # Sessions not supported.
#    1743     return None
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/pymongo/mongo_client.py:1685, in MongoClient.__start_session(self, implicit, **kwargs)
#    1682 def __start_session(self, implicit, **kwargs):
#    1683     # Raises ConfigurationError if sessions are not supported.
#    1684     if implicit:
# -> 1685         self._topology._check_implicit_session_support()
#    1686         server_session = _EmptyServerSession()
#    1687     else:
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/pymongo/topology.py:538, in Topology._check_implicit_session_support(self)
#     536 def _check_implicit_session_support(self):
#     537     with self._lock:
# --> 538         self._check_session_support()
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/pymongo/topology.py:554, in Topology._check_session_support(self)
#     550         self._select_servers_loop(
#     551             any_server_selector, self.get_server_selection_timeout(), None
#     552         )
#     553 elif not self._description.readable_servers:
# --> 554     self._select_servers_loop(
#     555         readable_server_selector, self.get_server_selection_timeout(), None
#     556     )
#     558 session_timeout = self._description.logical_session_timeout_minutes
#     559 if session_timeout is None:
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/pymongo/topology.py:238, in Topology._select_servers_loop(self, selector, timeout, address)
#     235 while not server_descriptions:
#     236     # No suitable servers.
#     237     if timeout == 0 or now > end_time:
# --> 238         raise ServerSelectionTimeoutError(
#     239             "%s, Timeout: %ss, Topology Description: %r"
#     240             % (self._error_message(selector), timeout, self.description)
#     241         )
#     243     self._ensure_opened()
#     244     self._request_check_all()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused, Timeout: 30s, Topology Description: <TopologyDescription id: 636c4ff592c6215bdb3038c1, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 61] Connection refused')>]>

# %% [markdown]
# # Step 4: Parse the hypertext with BeautifulSoup

# %%
# This is the beautiful part of soup. Parsing the HTML into a python object is effortless.

# %%
soup = BeautifulSoup(r.content, "html")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head><script src="/cf_scripts/scripts/cfform.js" type="text/javascript"></script>
# <script src="/cf_scripts/scripts/masks.js" type="text/javascript"></script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Watkins Marine Mammal Sound Database</title>
# <link href="https://www.whoi.edu/cf_headers/watkins/css/foundation.css" rel="stylesheet"/>
# <link href="https://www.whoi.edu/cf_headers/watkins/css/styles.css" rel="stylesheet"/>
# <link href="https://www.whoi.edu/cf_headers/watkins/css/audioplayer.css" rel="stylesheet"/>
# <script src="https://www.whoi.edu/cf_headers/watkins/js/vendor/modernizr.js"></script>
# <script>
# $('getSpeciesCommon').change(function(){
#     var url = $(this).val();
#     window.location = url;
# });
# 	</script>
# <script language="JavaScript">
# <!--
# function goTo(pagename) {
#     if ((-1 < pagename.selectedIndex) &&
#         (pagename.options[pagename.selectedIndex].value != "nil")) {
#         val = pagename.options[pagename.selectedIndex].value;
#         if(val!="NoValue") {
#             parent.location.href=val;
#             return true;
#         }
#     }
# }
#
# function popUpWin(theurl)
# {
#     window.open(theurl,"Metadata",
# "height=375,width=700,location=0,menubar=0,resizable=1,scrollbars=1,status=0,titlebar=1,toolbar=0,hotkeys=0,screenx=0,screeny=0,left=10,top=10");
# }
#
# //-->
# </script>
# <script type="text/javascript">
# <!--
#     _CF_checkjump1 = function(_CF_this)
#     {
#         //reset on submit
#         _CF_error_exists = false;
#         _CF_error_messages = new Array();
#         _CF_error_fields = new Object();
#         _CF_FirstErrorField = null;
#
#
#         //display error messages and return success
#         if( _CF_error_exists )
#         {
#             if( _CF_error_messages.length > 0 )
#             {
#                 // show alert() message
#                 _CF_onErrorAlert(_CF_error_messages);
#                 // set focus to first form error, if the field supports js focus().
#                 if( _CF_this[_CF_FirstErrorField].type == "text" )
#                 { _CF_this[_CF_FirstErrorField].focus(); }
#
#             }
#             return false;
#         }else {
#             return true;
#         }
#     }
# //-->
# </script>
# <script type="text/javascript">
# <!--
#     _CF_checkjump2 = function(_CF_this)
#     {
#         //reset on submit
#         _CF_error_exists = false;
#         _CF_error_messages = new Array();
#         _CF_error_fields = new Object();
#         _CF_FirstErrorField = null;
#
#
#         //display error messages and return success
#         if( _CF_error_exists )
#         {
#             if( _CF_error_messages.length > 0 )
#             {
#                 // show alert() message
#                 _CF_onErrorAlert(_CF_error_messages);
#                 // set focus to first form error, if the field supports js focus().
#                 if( _CF_this[_CF_FirstErrorField].type == "text" )
#                 { _CF_this[_CF_FirstErrorField].focus(); }
#
#             }
#             return false;
#         }else {
#             return true;
#         }
#     }
# //-->
# </script>
# </head>
# <body>
# <div class="brand">
# <div class="row">
# <div class="medium-6 columns">
# <a href="https://www.whalingmuseum.org/"><img alt="" src="https://www.whoi.edu/cf_headers/watkins/img/NBWM.png"/></a> </div>
# <div class="medium-6 columns"> <a href="https://www.whoi.edu"><img alt="Woods Hole Oceanographic Institution" src="https://www.whoi.edu/cf_headers/watkins/img/woodsholeoceanographic.png" style="padding-top:1.15em;float:right;"/></a> </div>
# </div>
# </div>
# <div class="banner">
# <div class="row">
# <div class="large-12 columns">
# <h1><a href="index.cfm"><img alt="" src="https://www.whoi.edu/cf_headers/watkins/img/logo.png"/>
# 	Watkins Marine Mammal Sound Database</a></h1>
# </div>
# </div>
# </div>
# <nav><div class="row">
# <div class="large-12 columns">
# <ul>
# <li class="active"><a href="index.cfm">‘Best of’ cuts</a></li>
# <li class="divider hidden-for-small-only"></li>
# <li><a href="fullCuts.cfm">All cuts</a></li>
# <li class="divider hidden-for-small-only"></li>
# <li><a href="masterFiles.cfm">Master Tapes</a></li>
# <li class="divider hidden-for-small-only"></li>
# <li><a href="about.cfm">About</a></li>
# <li class="divider hidden-for-small-only"></li>
# </ul>
# </div>
# </div></nav>
# <!--Search Database for all the 'best of' species        -->
# <div class="search-inside">
# <div class="row">
# <div class="large-12 columns"><h3>Search the database by name:</h3></div>
# <div class="large-6 medium-6 columns">
# <p>Common name:</p>
# <form action="/science/B/whalesounds/bestOf.cfm?code=BE3D" id="jump1" method="POST" name="jump1" onsubmit="return _CF_checkjump1(this)"><select id="getSpeciesCommon" name="getSpeciesCommon" onchange="location.href=jump1.getSpeciesCommon.options[selectedIndex].value">
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15F">
#                         Atlantic Spotted Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC2A">
#                         Bearded Seal</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB1A">
#                         Beluga, White Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD19D">
#                         Bottlenose Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA1A">
#                         Bowhead Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15B">
#                         Clymene Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD3B">
#                         Common Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE9A">
#                         False Killer Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1F">
#                         Fin, Finback Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD5A">
#                         Fraser's Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD4A">
#                         Grampus, Risso's Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC12G">
#                         Harp Seal</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC2A">
#                         Humpback Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE7A">
#                         Killer Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC4A">
#                         Leopard Seal</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3C">
#                         Long-Finned Pilot Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD10A">
#                         Melon Headed Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1A">
#                         Minke Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB2A">
#                         Narwhal</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3A">
#                         Northern Right Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15A">
#                         Pantropical Spotted Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC14A">
#                         Ross Seal</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD17A">
#                         Rough-Toothed Dolphin</option>
# <option selected="" value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3D">
#                         Short-Finned (Pacific) Pilot Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3B">
#                         Southern Right Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BA2A">
#                         Sperm Whale</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15L">
#                         Spinner Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15C">
#                         Striped Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CB1A">
#                         Walrus</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC5A">
#                         Weddell Seal</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6B">
#                         White-beaked Dolphin</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6A">
#                         White-sided Dolphin</option>
# </select></form>
# </div>
# <div class="large-6 medium-6 columns">
# <p>Scientific name: </p>
# <form action="/science/B/whalesounds/bestOf.cfm?code=BE3D" id="jump2" method="POST" name="jump2" onsubmit="return _CF_checkjump2(this)"><select id="getSpecies" name="getSpecies" onchange="location.href=jump2.getSpecies.options[selectedIndex].value">
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA1A">
# <i>Balaena mysticetus</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1A">
# <i>Balaenoptera acutorostrata</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1F">
# <i>Balaenoptera physalus</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB1A">
# <i>Delphinapterus leucas</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD3B">
# <i>Delphinus delphis</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC2A">
# <i>Erignathus barbatus</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3B">
# <i>Eubalaena australis</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3A">
# <i>Eubalaena glacialis</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3C">
# <i>Globicephala melas</i> (<i>Globicephala melaena, Globicephala edwardii</i>)
#
# 	    	</option>
# <option selected="" value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3D">
# <i>Globicephala macrorhynchus</i> (<i>Globicephala scammoni</i>)
#
# 	    	</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD4A">
# <i>Grampus griseus</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC4A">
# <i>Hydrurga leptonyx</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD5A">
# <i>Lagenodelphis hosei</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6A">
# <i>Lagenorhynchus acutus</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6B">
# <i>Lagenorhynchus albirostris</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC5A">
# <i>Leptonychotes weddellii</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC2A">
# <i>Megaptera novaeangliae</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB2A">
# <i>Monodon monoceros</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CB1A">
# <i>Odobenus rosmarus</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC14A">
# <i>Ommatophoca rossi</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE7A">
# <i>Orcinus orca</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD10A">
# <i>Peponocephala electra</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC12G">
# <i>Pagophilus groenlandicus</i> (<i>Phoca groenlandica</i>)
#
# 	    	</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BA2A">
# <i>Physeter macrocephalus</i> (<i>Physeter catodon</i>)
#
# 	    	</option>
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE9A">
# <i>Pseudorca crassidens</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15A">
# <i>Stenella attenuata</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15B">
# <i>Stenella clymene</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15C">
# <i>Stenella coeruleoalba</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15F">
# <i>Stenella frontalis</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15L">
# <i>Stenella longirostris</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD17A">
# <i>Steno bredanensis</i></option>
#
# <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD19D">
# <i>Tursiops truncatus</i> (<i>Tursiops gilli</i>)
#
# 	    	</option>
# </select></form>
# </div>
# </div>
# </div>
# <div class="database">
# <div class="row">
# <div class="large-12 columns">
# <h3>Best of Short-Finned (Pacific) Pilot Whale
# (<i>Globicephala macrorhynchus/Globicephala scammoni</i>)
# 	      	67 sound cut
# 		files</h3>
# <p>See the 'About' section for <a href="about.cfm#credit" target="_blank">crediting</a> and
# 	<a href="about.cfm#download" target="_blank">download instructions</a>.</p>
# <table>
# <tr><th>Sound cut file</th>
# <th>Location</th>
# <th>Observation Date</th>
# <th><strong>Download link</strong></th>
# <th><strong>Metadata</strong></th>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/57021001.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>NW arm of Tongue of the Ocean, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/57021001.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=57021001');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/57021002.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>16-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/57021002.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=57021002');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/57021003.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>16-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/57021003.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=57021003');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/57021004.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>16-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/57021004.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=57021004');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/57021005.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/57021005.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=57021005');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/57021007.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>NW arm of Tongue of the Ocean, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/57021007.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=57021007');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/57021008.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>16-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/57021008.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=57021008');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/57021009.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>16-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/57021009.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=57021009');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100A.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>16-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100A.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100A');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100B.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>16-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100B.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100B');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100C.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>16-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100C.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100C');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100D.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100D.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100D');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100E.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100E.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100E');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100F.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100F.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100F');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100G.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>NW arm of Tongue of the Ocean, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100G.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100G');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100H.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>NW arm of Tongue of the Ocean, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100H.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100H');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100I.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>NW arm of Tongue of the Ocean, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100I.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100I');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100J.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100J.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100J');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100K.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100K.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100K');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100L.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100L.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100L');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/5702100N.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 miles NW of Bimini, Northern Bahamas  BE3B</td>
# <td>21-Mar-1957  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/5702100N.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=5702100N');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/81037001.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/81037001.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=81037001');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/81037002.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/81037002.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=81037002');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/81037004.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/81037004.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=81037004');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/81037005.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/81037005.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=81037005');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/81037007.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/81037007.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=81037007');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/81037008.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/81037008.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=81037008');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700A.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700A.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700A');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700B.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700B.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700B');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700C.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700C.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700C');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700E.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700E.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700E');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700F.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700F.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700F');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700G.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700G.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700G');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700H.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700H.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700H');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700L.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700L.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700L');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700P.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700P.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700P');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700U.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700U.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700U');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8103700V.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8103700V.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8103700V');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/81037011.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>11 mi. WSW West Cay, Bequia  BE3B</td>
# <td>23-Nov-1981  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/81037011.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=81037011');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/84016002.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>N end of Dominica  BE3B  BA2A</td>
# <td>20-Mar-1984  BA2A  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/84016002.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=84016002');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/8401600B.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>N end of Dominica  BE3B  BA2A</td>
# <td>20-Mar-1984  BA2A  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/8401600B.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=8401600B');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005006.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005006.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005006');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100500N.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100500N.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100500N');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100500R.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100500R.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100500R');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100500S.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100500S.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100500S');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100500Y.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100500Y.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100500Y');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005010.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005010.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005010');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005011.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005011.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005011');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005012.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005012.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005012');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005014.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005014.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005014');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005015.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005015.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005015');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100501D.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100501D.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100501D');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100501K.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100501K.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100501K');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100501S.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100501S.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100501S');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100501T.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100501T.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100501T');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100501V.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100501V.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100501V');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100501W.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100501W.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100501W');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005020.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005020.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005020');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005029.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B</td>
# <td>23-Oct-1991  BE3B </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005029.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005029');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100502F.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100502F.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100502F');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100502M.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100502M.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100502M');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005036.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005036.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005036');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/91005039.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/91005039.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=91005039');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100503E.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100503E.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100503E');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100503J.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100503J.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100503J');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100503O.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100503O.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100503O');">Metadata</a></td>
# </tr>
# <tr><td><audio controls="">
# <source src="/science/B/whalesounds/WhaleSounds/9100503P.wav" type="audio/wav"/>
# </audio>
# </td>
# <td>Dominica  BE3B  X</td>
# <td>23-Oct-1991  BE3B  X </td>
# <td><a href="/science/B/whalesounds/WhaleSounds/9100503P.wav" target="_blank">Download</a></td>
# <td><a href="javascript:popUpWin('metaData.cfm?RN=9100503P');">Metadata</a></td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <!-- footer -->
# <footer>
# <div class="row">
# <div class="large-9 columns"><p>This database was proudly funded by:</p>
# <div class="row">
# <div class="large-6 columns"><a href="https://www.whoi.edu/website/mmc/home/"><img alt="" src="https://www.whoi.edu/cf_headers/watkins/img/logo-mmc.png"/></a>
# </div>
# <div class="large-6 columns"><p>The Marine Mammal Center conducts basic research, using cutting-edge
# 	technology to solve major scientific and conservation challenges. Its scientists and engineers
# 	integrate diverse approaches and methods to understanding marine mammals and the different ways
# 	humans may influence their health, populations, and ecosystems.</p></div>
# </div>
# </div>
# <div class="large-3 columns"><p> </p>
# <p>©<script type="text/javascript">var year = new Date();document.write(year.getFullYear());</script>
#       Watkins Marine Mammal Sound Database. All rights reserved.
#       For trouble with this site, contact:
# 	<a href="mailto:webapp-support@whoi.edu">webapp-support@whoi.edu</a></p>
# </div>
# </div>
# </footer>
# <script>
#   $(document).foundation();
# </script>
# <script src="https://www.whoi.edu/cf_headers/watkins/js/vendor/jquery.js"></script>
# <script src="https://www.whoi.edu/cf_headers/watkins/js/foundation.min.js"></script>
# <script src="https://www.whoi.edu/cf_headers/watkins/js/jquery.js"></script>
# <script src="https://www.whoi.edu/cf_headers/watkins/js/audioplayer.js"></script>
# <script>$(document).foundation();</script>
# <script>$( function() {$('audio').audioPlayer();});</script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-77353200-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <script src="/cf_scripts/scripts/cfform.js" type="text/javascript">
#   </script>
#   <script src="/cf_scripts/scripts/masks.js" type="text/javascript">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Watkins Marine Mammal Sound Database
#   </title>
#   <link href="https://www.whoi.edu/cf_headers/watkins/css/foundation.css" rel="stylesheet"/>
#   <link href="https://www.whoi.edu/cf_headers/watkins/css/styles.css" rel="stylesheet"/>
#   <link href="https://www.whoi.edu/cf_headers/watkins/css/audioplayer.css" rel="stylesheet"/>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/vendor/modernizr.js">
#   </script>
#   <script>
#    $('getSpeciesCommon').change(function(){
#     var url = $(this).val();
#     window.location = url;
# });
#   </script>
#   <script language="JavaScript">
#    <!--
# function goTo(pagename) {
#     if ((-1 < pagename.selectedIndex) &&
#         (pagename.options[pagename.selectedIndex].value != "nil")) {
#         val = pagename.options[pagename.selectedIndex].value;
#         if(val!="NoValue") {
#             parent.location.href=val;
#             return true;
#         }
#     }
# }
#
# function popUpWin(theurl)
# {
#     window.open(theurl,"Metadata",
# "height=375,width=700,location=0,menubar=0,resizable=1,scrollbars=1,status=0,titlebar=1,toolbar=0,hotkeys=0,screenx=0,screeny=0,left=10,top=10");
# }
#
# //-->
#   </script>
#   <script type="text/javascript">
#    <!--
#     _CF_checkjump1 = function(_CF_this)
#     {
#         //reset on submit
#         _CF_error_exists = false;
#         _CF_error_messages = new Array();
#         _CF_error_fields = new Object();
#         _CF_FirstErrorField = null;
#
#
#         //display error messages and return success
#         if( _CF_error_exists )
#         {
#             if( _CF_error_messages.length > 0 )
#             {
#                 // show alert() message
#                 _CF_onErrorAlert(_CF_error_messages);
#                 // set focus to first form error, if the field supports js focus().
#                 if( _CF_this[_CF_FirstErrorField].type == "text" )
#                 { _CF_this[_CF_FirstErrorField].focus(); }
#
#             }
#             return false;
#         }else {
#             return true;
#         }
#     }
# //-->
#   </script>
#   <script type="text/javascript">
#    <!--
#     _CF_checkjump2 = function(_CF_this)
#     {
#         //reset on submit
#         _CF_error_exists = false;
#         _CF_error_messages = new Array();
#         _CF_error_fields = new Object();
#         _CF_FirstErrorField = null;
#
#
#         //display error messages and return success
#         if( _CF_error_exists )
#         {
#             if( _CF_error_messages.length > 0 )
#             {
#                 // show alert() message
#                 _CF_onErrorAlert(_CF_error_messages);
#                 // set focus to first form error, if the field supports js focus().
#                 if( _CF_this[_CF_FirstErrorField].type == "text" )
#                 { _CF_this[_CF_FirstErrorField].focus(); }
#
#             }
#             return false;
#         }else {
#             return true;
#         }
#     }
# //-->
#   </script>
#  </head>
#  <body>
#   <div class="brand">
#    <div class="row">
#     <div class="medium-6 columns">
#      <a href="https://www.whalingmuseum.org/">
#       <img alt="" src="https://www.whoi.edu/cf_headers/watkins/img/NBWM.png"/>
#      </a>
#     </div>
#     <div class="medium-6 columns">
#      <a href="https://www.whoi.edu">
#       <img alt="Woods Hole Oceanographic Institution" src="https://www.whoi.edu/cf_headers/watkins/img/woodsholeoceanographic.png" style="padding-top:1.15em;float:right;"/>
#      </a>
#     </div>
#    </div>
#   </div>
#   <div class="banner">
#    <div class="row">
#     <div class="large-12 columns">
#      <h1>
#       <a href="index.cfm">
#        <img alt="" src="https://www.whoi.edu/cf_headers/watkins/img/logo.png"/>
#        Watkins Marine Mammal Sound Database
#       </a>
#      </h1>
#     </div>
#    </div>
#   </div>
#   <nav>
#    <div class="row">
#     <div class="large-12 columns">
#      <ul>
#       <li class="active">
#        <a href="index.cfm">
#         ‘Best of’ cuts
#        </a>
#       </li>
#       <li class="divider hidden-for-small-only">
#       </li>
#       <li>
#        <a href="fullCuts.cfm">
#         All cuts
#        </a>
#       </li>
#       <li class="divider hidden-for-small-only">
#       </li>
#       <li>
#        <a href="masterFiles.cfm">
#         Master Tapes
#        </a>
#       </li>
#       <li class="divider hidden-for-small-only">
#       </li>
#       <li>
#        <a href="about.cfm">
#         About
#        </a>
#       </li>
#       <li class="divider hidden-for-small-only">
#       </li>
#      </ul>
#     </div>
#    </div>
#   </nav>
#   <!--Search Database for all the 'best of' species        -->
#   <div class="search-inside">
#    <div class="row">
#     <div class="large-12 columns">
#      <h3>
#       Search the database by name:
#      </h3>
#     </div>
#     <div class="large-6 medium-6 columns">
#      <p>
#       Common name:
#      </p>
#      <form action="/science/B/whalesounds/bestOf.cfm?code=BE3D" id="jump1" method="POST" name="jump1" onsubmit="return _CF_checkjump1(this)">
#       <select id="getSpeciesCommon" name="getSpeciesCommon" onchange="location.href=jump1.getSpeciesCommon.options[selectedIndex].value">
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15F">
#         Atlantic Spotted Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC2A">
#         Bearded Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB1A">
#         Beluga, White Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD19D">
#         Bottlenose Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA1A">
#         Bowhead Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15B">
#         Clymene Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD3B">
#         Common Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE9A">
#         False Killer Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1F">
#         Fin, Finback Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD5A">
#         Fraser's Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD4A">
#         Grampus, Risso's Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC12G">
#         Harp Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC2A">
#         Humpback Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE7A">
#         Killer Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC4A">
#         Leopard Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3C">
#         Long-Finned Pilot Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD10A">
#         Melon Headed Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1A">
#         Minke Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB2A">
#         Narwhal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3A">
#         Northern Right Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15A">
#         Pantropical Spotted Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC14A">
#         Ross Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD17A">
#         Rough-Toothed Dolphin
#        </option>
#        <option selected="" value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3D">
#         Short-Finned (Pacific) Pilot Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3B">
#         Southern Right Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BA2A">
#         Sperm Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15L">
#         Spinner Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15C">
#         Striped Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CB1A">
#         Walrus
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC5A">
#         Weddell Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6B">
#         White-beaked Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6A">
#         White-sided Dolphin
#        </option>
#       </select>
#      </form>
#     </div>
#     <div class="large-6 medium-6 columns">
#      <p>
#       Scientific name:
#      </p>
#      <form action="/science/B/whalesounds/bestOf.cfm?code=BE3D" id="jump2" method="POST" name="jump2" onsubmit="return _CF_checkjump2(this)">
#       <select id="getSpecies" name="getSpecies" onchange="location.href=jump2.getSpecies.options[selectedIndex].value">
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA1A">
#         <i>
#          Balaena mysticetus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1A">
#         <i>
#          Balaenoptera acutorostrata
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1F">
#         <i>
#          Balaenoptera physalus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB1A">
#         <i>
#          Delphinapterus leucas
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD3B">
#         <i>
#          Delphinus delphis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC2A">
#         <i>
#          Erignathus barbatus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3B">
#         <i>
#          Eubalaena australis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3A">
#         <i>
#          Eubalaena glacialis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3C">
#         <i>
#          Globicephala melas
#         </i>
#         (
#         <i>
#          Globicephala melaena, Globicephala edwardii
#         </i>
#         )
#        </option>
#        <option selected="" value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3D">
#         <i>
#          Globicephala macrorhynchus
#         </i>
#         (
#         <i>
#          Globicephala scammoni
#         </i>
#         )
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD4A">
#         <i>
#          Grampus griseus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC4A">
#         <i>
#          Hydrurga leptonyx
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD5A">
#         <i>
#          Lagenodelphis hosei
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6A">
#         <i>
#          Lagenorhynchus acutus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6B">
#         <i>
#          Lagenorhynchus albirostris
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC5A">
#         <i>
#          Leptonychotes weddellii
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC2A">
#         <i>
#          Megaptera novaeangliae
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB2A">
#         <i>
#          Monodon monoceros
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CB1A">
#         <i>
#          Odobenus rosmarus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC14A">
#         <i>
#          Ommatophoca rossi
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE7A">
#         <i>
#          Orcinus orca
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD10A">
#         <i>
#          Peponocephala electra
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC12G">
#         <i>
#          Pagophilus groenlandicus
#         </i>
#         (
#         <i>
#          Phoca groenlandica
#         </i>
#         )
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BA2A">
#         <i>
#          Physeter macrocephalus
#         </i>
#         (
#         <i>
#          Physeter catodon
#         </i>
#         )
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE9A">
#         <i>
#          Pseudorca crassidens
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15A">
#         <i>
#          Stenella attenuata
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15B">
#         <i>
#          Stenella clymene
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15C">
#         <i>
#          Stenella coeruleoalba
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15F">
#         <i>
#          Stenella frontalis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15L">
#         <i>
#          Stenella longirostris
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD17A">
#         <i>
#          Steno bredanensis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD19D">
#         <i>
#          Tursiops truncatus
#         </i>
#         (
#         <i>
#          Tursiops gilli
#         </i>
#         )
#        </option>
#       </select>
#      </form>
#     </div>
#    </div>
#   </div>
#   <div class="database">
#    <div class="row">
#     <div class="large-12 columns">
#      <h3>
#       Best of Short-Finned (Pacific) Pilot Whale
# (
#       <i>
#        Globicephala macrorhynchus/Globicephala scammoni
#       </i>
#       )
# 	      	67 sound cut
# 		files
#      </h3>
#      <p>
#       See the 'About' section for
#       <a href="about.cfm#credit" target="_blank">
#        crediting
#       </a>
#       and
#       <a href="about.cfm#download" target="_blank">
#        download instructions
#       </a>
#       .
#      </p>
#      <table>
#       <tr>
#        <th>
#         Sound cut file
#        </th>
#        <th>
#         Location
#        </th>
#        <th>
#         Observation Date
#        </th>
#        <th>
#         <strong>
#          Download link
#         </strong>
#        </th>
#        <th>
#         <strong>
#          Metadata
#         </strong>
#        </th>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/57021001.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         NW arm of Tongue of the Ocean, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/57021001.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=57021001');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/57021002.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         16-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/57021002.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=57021002');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/57021003.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         16-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/57021003.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=57021003');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/57021004.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         16-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/57021004.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=57021004');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/57021005.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/57021005.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=57021005');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/57021007.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         NW arm of Tongue of the Ocean, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/57021007.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=57021007');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/57021008.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         16-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/57021008.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=57021008');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/57021009.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         16-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/57021009.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=57021009');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100A.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         16-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100A.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100A');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100B.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         16-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100B.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100B');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100C.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         16-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100C.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100C');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100D.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100D.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100D');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100E.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100E.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100E');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100F.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100F.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100F');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100G.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         NW arm of Tongue of the Ocean, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100G.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100G');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100H.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         NW arm of Tongue of the Ocean, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100H.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100H');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100I.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         NW arm of Tongue of the Ocean, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100I.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100I');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100J.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100J.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100J');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100K.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100K.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100K');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100L.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100L.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100L');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/5702100N.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 miles NW of Bimini, Northern Bahamas  BE3B
#        </td>
#        <td>
#         21-Mar-1957  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/5702100N.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=5702100N');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/81037001.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/81037001.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=81037001');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/81037002.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/81037002.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=81037002');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/81037004.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/81037004.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=81037004');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/81037005.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/81037005.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=81037005');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/81037007.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/81037007.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=81037007');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/81037008.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/81037008.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=81037008');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700A.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700A.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700A');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700B.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700B.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700B');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700C.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700C.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700C');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700E.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700E.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700E');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700F.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700F.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700F');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700G.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700G.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700G');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700H.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700H.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700H');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700L.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700L.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700L');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700P.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700P.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700P');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700U.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700U.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700U');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8103700V.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8103700V.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8103700V');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/81037011.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         11 mi. WSW West Cay, Bequia  BE3B
#        </td>
#        <td>
#         23-Nov-1981  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/81037011.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=81037011');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/84016002.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         N end of Dominica  BE3B  BA2A
#        </td>
#        <td>
#         20-Mar-1984  BA2A  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/84016002.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=84016002');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/8401600B.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         N end of Dominica  BE3B  BA2A
#        </td>
#        <td>
#         20-Mar-1984  BA2A  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/8401600B.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=8401600B');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005006.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005006.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005006');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100500N.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100500N.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100500N');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100500R.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100500R.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100500R');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100500S.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100500S.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100500S');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100500Y.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100500Y.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100500Y');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005010.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005010.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005010');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005011.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005011.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005011');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005012.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005012.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005012');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005014.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005014.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005014');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005015.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005015.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005015');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100501D.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100501D.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100501D');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100501K.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100501K.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100501K');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100501S.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100501S.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100501S');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100501T.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100501T.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100501T');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100501V.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100501V.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100501V');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100501W.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100501W.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100501W');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005020.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005020.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005020');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005029.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B
#        </td>
#        <td>
#         23-Oct-1991  BE3B
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005029.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005029');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100502F.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100502F.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100502F');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100502M.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100502M.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100502M');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005036.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005036.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005036');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/91005039.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/91005039.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=91005039');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100503E.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100503E.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100503E');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100503J.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100503J.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100503J');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100503O.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100503O.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100503O');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/9100503P.wav" type="audio/wav"/>
#         </audio>
#        </td>
#        <td>
#         Dominica  BE3B  X
#        </td>
#        <td>
#         23-Oct-1991  BE3B  X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/9100503P.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=9100503P');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#   </div>
#   <!-- footer -->
#   <footer>
#    <div class="row">
#     <div class="large-9 columns">
#      <p>
#       This database was proudly funded by:
#      </p>
#      <div class="row">
#       <div class="large-6 columns">
#        <a href="https://www.whoi.edu/website/mmc/home/">
#         <img alt="" src="https://www.whoi.edu/cf_headers/watkins/img/logo-mmc.png"/>
#        </a>
#       </div>
#       <div class="large-6 columns">
#        <p>
#         The Marine Mammal Center conducts basic research, using cutting-edge
# 	technology to solve major scientific and conservation challenges. Its scientists and engineers
# 	integrate diverse approaches and methods to understanding marine mammals and the different ways
# 	humans may influence their health, populations, and ecosystems.
#        </p>
#       </div>
#      </div>
#     </div>
#     <div class="large-3 columns">
#      <p>
#      </p>
#      <p>
#       ©
#       <script type="text/javascript">
#        var year = new Date();document.write(year.getFullYear());
#       </script>
#       Watkins Marine Mammal Sound Database. All rights reserved.
#       For trouble with this site, contact:
#       <a href="mailto:webapp-support@whoi.edu">
#        webapp-support@whoi.edu
#       </a>
#      </p>
#     </div>
#    </div>
#   </footer>
#   <script>
#    $(document).foundation();
#   </script>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/vendor/jquery.js">
#   </script>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/foundation.min.js">
#   </script>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/jquery.js">
#   </script>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/audioplayer.js">
#   </script>
#   <script>
#    $(document).foundation();
#   </script>
#   <script>
#    $( function() {$('audio').audioPlayer();});
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-77353200-1', 'auto');
#   ga('send', 'pageview');
#   </script>
#  </body>
# </html>

# %%
print(soup.title)
# Out:
# <title>Watkins Marine Mammal Sound Database</title>

# %% [markdown]
# # Step 5: Navigate the data to pull out the table information
#
# Recall the structure of the table we are looking for:

# %%
div = soup.find("div", {"class": "database"})

table = div.find("table")

# %%
# This returns an iterator over the rows in the table
rows = table.find_all("tr")

# %%
import re 

links = [a['href'] for a in soup.find_all('a',href=re.compile('/science.*\.(mp3|wav|ogg|wma)'))]

# %%
from pydub import AudioSegment
from pydub.playback import play

# %% [markdown]
# # Scrape Audio:
#
# * First create the directory for the class in the data directory.
#
# * Second rename with open(f'data/northern right whale/rightWhale{idx}.wav', 'wb') to the just created path
#
# * The data flow is first download the raw audio data here and them concatenate the audio into the training dataset directory into 30 seconds chucks.

# %%
def download_audio_and_save(lst_of_urls):
    
    for idx, url in enumerate(lst_of_urls):
        doc = requests.get(f'https://whoicf2.whoi.edu{url}')

        with open(f'data/short-finned-pilot-whale/pilotWhale{idx}.wav', 'wb') as f:
            f.write(doc.content)
            print(f"Saved audio file{idx}")

# %%
download_audio_and_save(links)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 download_audio_and_save(links)
#
# Cell In [24], line 6, in download_audio_and_save(lst_of_urls)
#       3 for idx, url in enumerate(lst_of_urls):
#       4     doc = requests.get(f'https://whoicf2.whoi.edu{url}')
# ----> 6     with open(f'data/short-finned-pilot-whale/pilotWhale{idx}.wav', 'wb') as f:
#       7         f.write(doc.content)
#       8         print(f"Saved audio file{idx}")
#
# File ~/Documents/classifying_marine_mammals_vocals_with_CNN_and_Dolby/mammal-env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/short-finned-pilot-whale/pilotWhale0.wav'
