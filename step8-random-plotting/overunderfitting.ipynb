# %%
import matplotlib.pyplot as plt
import numpy as np
# manual input for overfitting and underfitting plots 
x3 = [
    333519,
    441859,
    984099,
    0.68e7,
    1.31e7,
    1.96e7,
    2.59e7,
    3.37e7,
    4.09e7,
    ]
y3 = [
    0.718276810,
    0.792616726,
    0.921875821,
    0.927986871,
    0.916720348,
    0.890915672,
    0.817617320,
    0.743710921,
    0.709814126,
    ]

x5 = [  
    0.02e7,
    0.18e7,
    0.31e7,
    0.64e7,
    1.22e7,
    2.04e7,
    2.38e7,
    3.22e7,
    4.48e7,
    5.57e7
    ]
y5 = [  
    0.8517291,
    0.92167571,
    0.95677619,
    0.97916783,
    0.96671986,
    0.93513415,
    0.92798710,
    0.88673532,
    0.86623412,
    0.82313537,
    ]

x7 = [
    1745383,  
    13861721, 
    20433921, 
    27366121, 
    34658321, 
    42310521, 
    50322721, 
    67427121,
    84354519, 
    86089819,  
] 

y7 = [
    0.9750, 
    0.9885, 
    0.9775, 
    0.9790, 
    0.9655, 
    0.9665, 
    0.9470, 
    0.8600,  
    0.8183333277702332, 
    0.7386666536331177, 
] 

x3[:] = [x / 1000000 for x in x3]
x5[:] = [x / 1000000 for x in x5]
x7[:] = [x / 1000000 for x in x7]
y3[:] = [x*100 for x in y3]
y5[:] = [x*100 for x in y5]
y7[:] = [x*100 for x in y7]


plt.plot(x3, y3, '--o', color='blue')
plt.plot(x5, y5, '--o', color='red')
plt.plot(x7, y7, '--o', color='green')
plt.xlabel("Number of Trainable Parameters (10e6)", fontsize=16)
plt.ylabel("Model Accuracy (%)", fontsize=16)
plt.legend(["3 Layer Models", "5 Layer Models", "7 Layer Models"], fontsize=10)
plt.savefig("../over-under-fitting-layers-3-5-7.png")
#plt.xlim(0, 6e7)
#plt.ylim(0.6, 1)
